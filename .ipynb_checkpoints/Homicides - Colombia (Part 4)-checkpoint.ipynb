# %% [markdown]
# # Homicides - Colombia (Part 4)

# %% [markdown]
# For this part of the project, I will be using data for Colombia's intentional homicides rates.
#
# **Skills:** geopandas

# %% [markdown]
# **import libraries**

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
col_map_n0 = gpd.read_file('COL_adm_shp/COL_adm0.shp')
col_map_n1 = gpd.read_file('COL_adm_shp/COL_adm1.shp')
col_map_n2 = gpd.read_file('COL_adm_shp/COL_adm2.shp')

# %%
col_map_n0.plot()

# %%
col_map_n1.plot()

# %%
col_map_n2.plot()

# %%
col_map_n1.head(3)
# Out:
#    ID_0  ISO    NAME_0  ID_1     NAME_1 HASC_1  CCN_1 CCA_1        TYPE_1  \
# 0    53  COL  Colombia     1   Amazonas  CO.AM      0  None     Comisaría
# 1    53  COL  Colombia     2  Antioquia  CO.AN      0  None  Departamento
# 2    53  COL  Colombia     3     Arauca  CO.AR      0  None   Intendencia
#
#      ENGTYPE_1 NL_NAME_1 VARNAME_1  \
# 0  Commissiary      None      None
# 1   Department      None      None
# 2   Intendancy      None      None
#
#                                             geometry
# 0  (POLYGON ((-69.43138122558594 -1.0784740447997...
# 1  (POLYGON ((-76.92485809326172 8.21236133575439...
# 2  POLYGON ((-70.68779754638672 7.090909957885799...
